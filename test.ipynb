# %%
class Watch:
    def __enter__(self):
        print("enter")
        return self

    def __exit__(self, exc_type, exc, tb):
        print("exc_type:", exc_type)
        print("exc:", exc)
        print("tb: ", tb)
        return False

with Watch():
    1 / 0
# Out:
# enter
# exc_type: <class 'ZeroDivisionError'>
# exc: division by zero
# tb:  <traceback object at 0x00000290E2949F80>
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 13
#       9         print("tb: ", tb)
#      10         return False
#      11
#      12 with Watch():
# ---> 13     1 / 0
#
# ZeroDivisionError: division by zero
